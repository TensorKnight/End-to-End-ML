# %% [markdown]
# ### 1.0. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.1. Load Dataset

# %%
df = pd.read_csv('datasets/data.csv')

# %% [markdown]
# ### 2.0. Show top 5 records

# %%
df.head()
# Out:
#   Area Name  Daily Min Temp  Daily Max Temp  Daily Avg Temp  \
# 0    Area 1           20.62           29.55           25.09
# 1    Area 2           29.26           39.00           34.13
# 2    Area 3           25.98           39.53           32.75
# 3    Area 4           23.98           32.38           28.18
# 4    Area 5           17.34           31.04           24.19
#
#    Total Precipitation  Relative Humidity  Water Bodies  Population Density  \
# 0                37.36              64.98             1                7677
# 1                33.29              77.34             0                3811
# 2                17.62              68.13             0                3060
# 3                60.73              44.17             0                4930
# 4                47.66              49.28             0                5558
#
#    Day Length  Urban / Rural Area  Forested Area  Crop Area  Graze Land Area  \
# ...

# %% [markdown]
# ### 2.1. Shape of dataset

# %%
df.shape
# Out:
# (5000, 14)

# %% [markdown]
# ### 2.2. Dataset Description

# %% [markdown]
# Given dataset consists of climate and geographical variables :
#
# * **Area Name**: Unique identifier for each geographical area.
# * **Daily Min Temp**: Minimum daily temperature (in °C).
# * **Daily Max Temp**: Maximum daily temperature (in °C).
# * **Daily Avg Temp**: Average daily temperature (in °C).
# * **Total Precipitation**: Total daily precipitation (in mm).
# * **Relative Humidity**: Average relative humidity (in %).
# * **Water Bodies**: Binary flag indicating presence (1) or absence (0) of nearby water bodies.
# * **Population Density**: Number of people per square kilometer.
# * **Day Length**: Duration of daylight in hours.
# * **Urban / Rural Area**: Categorical binary flag where 1 = Urban, 0 = Rural.
# * **Forested Area**: Binary indicator of presence of forested land (1 = Yes, 0 = No).
# * **Crop Area**: Binary indicator for presence of agricultural land.
# * **Graze Land Area**: Binary indicator for grazing land presence.
# * **Habitable**: Target variable — indicates whether the area is habitable (1 = Yes, 0 = No).

# %% [markdown]
# ### 2.3. Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area Name            5000 non-null   object
#  1   Daily Min Temp       5000 non-null   float64
#  2   Daily Max Temp       5000 non-null   float64
#  3   Daily Avg Temp       5000 non-null   float64
#  4   Total Precipitation  5000 non-null   float64
#  5   Relative Humidity    5000 non-null   float64
#  6   Water Bodies         5000 non-null   int64
#  7   Population Density   5000 non-null   int64
#  8   Day Length           5000 non-null   float64
#  9   Urban / Rural Area   5000 non-null   int64
#  10  Forested Area        5000 non-null   int64
#  11  Crop Area            5000 non-null   int64
#  12  Graze Land Area      5000 non-null   int64
#  13  Habitable            5000 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 547.0+ KB

# %% [markdown]
# ### 3. Data Checks to perform

# %% [markdown]
# * Check missing values
# * Check Duplicates
# * Check Data types
# * Check number of unique value in each column
# * Check statistics of dataset
# * Check various categories present in different categorical columns

# %% [markdown]
# ### 3.0. Check missing values

# %%
df.isnull().sum()
# Out:
# Area Name              0
# Daily Min Temp         0
# Daily Max Temp         0
# Daily Avg Temp         0
# Total Precipitation    0
# Relative Humidity      0
# Water Bodies           0
# Population Density     0
# Day Length             0
# Urban / Rural Area     0
# Forested Area          0
# Crop Area              0
# Graze Land Area        0
# Habitable              0
# dtype: int64

# %% [markdown]
# No missing values found

# %% [markdown]
# ### 3.1. Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates found

# %% [markdown]
# ### 3.2. Check data types

# %%
df.dtypes
# Out:
# Area Name               object
# Daily Min Temp         float64
# Daily Max Temp         float64
# Daily Avg Temp         float64
# Total Precipitation    float64
# Relative Humidity      float64
# Water Bodies             int64
# Population Density       int64
# Day Length             float64
# Urban / Rural Area       int64
# Forested Area            int64
# Crop Area                int64
# Graze Land Area          int64
# Habitable                int64
# dtype: object

# %% [markdown]
# ### 3.3. Check unique values per column

# %%
df.nunique()
# Out:
# Area Name              5000
# Daily Min Temp         1440
# Daily Max Temp         1910
# Daily Avg Temp         1666
# Total Precipitation    3918
# Relative Humidity      3132
# Water Bodies              2
# Population Density     3920
# Day Length              401
# Urban / Rural Area        2
# Forested Area             2
# Crop Area                 2
# Graze Land Area           2
# Habitable                 2
# dtype: int64

# %% [markdown]
# ### 3.4. Check statistical summary

# %%
df.describe(include='all')
# Out:
#        Area Name  Daily Min Temp  Daily Max Temp  Daily Avg Temp  \
# count       5000     5000.000000     5000.000000     5000.000000
# unique      5000             NaN             NaN             NaN
# top       Area 1             NaN             NaN             NaN
# freq           1             NaN             NaN             NaN
# mean         NaN       22.452496       32.367414       27.410064
# std          NaN        4.344518        5.182502        4.563592
# min          NaN       15.000000       20.190000       17.640000
# 25%          NaN       18.657500       28.550000       23.717500
# 50%          NaN       22.500000       32.310000       27.410000
# 75%          NaN       26.220000       36.180000       31.090000
# max          NaN       30.000000       44.670000       37.210000
#
#         Total Precipitation  Relative Humidity  Water Bodies  \
# count           5000.000000        5000.000000   5000.000000
# ...

# %% [markdown]
# #### General Overview
#
# * The dataset contains 5,000 unique areas described by weather, environment, land usage features, and a binary Habitable label.
#
# #### Temperature Insights
#
# * Daily Min Temp ranges from 15.0°C to 30.0°C with an average of 22.45°C; Daily Max Temp ranges from 20.19°C to 44.67°C averaging 32.37°C; Daily Avg Temp averages 27.41°C indicating warm climates.
#
# #### Precipitation & Humidity
#
# * Total Precipitation ranges from 0.02 mm to 99.98 mm (mean 50.14 mm) showing dry and rainy regions; Relative Humidity varies from 40.01% to 90% with an average of 65.38%.
#
# #### Water Bodies
#
# * The Water Bodies column is binary with a mean of 0.31, indicating about 31% of areas have nearby water bodies.
#
# #### Population Density & Urbanization
#
# * Population Density spans 100 to 9999 with an average of 5030; Urban / Rural Area is binary with a mean of 0.386, suggesting 38.6% of regions are urban.
#
# #### Land Use
#
# * Forested Area, Crop Area, and Graze Land Area are binary columns; on average, 50% of areas are covered by forests, crops, or grazing land.
#
# #### Day Length
#
# * Day Length ranges from 10 to 14 hours with an average of 11.99 hours, indicating normal seasonal variation.
#
# #### Target Variable: Habitable
#
# * Habitable is binary with a mean of 0.3828, meaning about 38.3% of areas are considered habitable.

# %% [markdown]
# ### 3.5. Check categories in categorical columns

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    print(f"{col} --> {df[col].unique()}")
# Out:
# Area Name --> ['Area 1' 'Area 2' 'Area 3' ... 'Area 4998' 'Area 4999' 'Area 5000']

# %% [markdown]
# ### 3.6. Numerical and Categorical features

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numerical Features:")
print(numerical_features)

categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()
print("Categorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
# ['Daily Min Temp', 'Daily Max Temp', 'Daily Avg Temp', 'Total Precipitation', 'Relative Humidity', 'Water Bodies', 'Population Density', 'Day Length', 'Urban / Rural Area', 'Forested Area', 'Crop Area', 'Graze Land Area', 'Habitable']
# Categorical Features:
# ['Area Name']

# %% [markdown]
# ### 3.7. Feature Engineering

# %% [markdown]
# #### 3.7.0. Natural resource score

# %%
df['Natural Resource Score'] = df[['Forested Area', 'Water Bodies', 'Crop Area', 'Graze Land Area']].sum(axis=1)

# %% [markdown]
# #### 3.7.1. Humidity Temprature Score

# %%
df['Humidity_Temp'] = df['Relative Humidity'] * df['Daily Avg Temp']

# %% [markdown]
# ### 3.8. Visualization

# %% [markdown]
# #### 3.8.0. Numerical Feature distribution

# %%
num_cols = df.select_dtypes(include='number').columns.tolist()
df[num_cols].hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.suptitle('Distributions of Numerical Features', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight :
#
# 1. **Daily Min Temp** – Normally distributed, useful as-is for modeling.
# 2. **Daily Max Temp** – Bell-shaped curve, strong candidate without transformation.
# 3. **Daily Avg Temp** – Symmetric distribution, likely a key predictor.
# 4. **Total Precipitation** – Uniformly distributed; binning may improve interpretability.
# 5. **Relative Humidity** – Evenly spread, may interact meaningfully with temperature.
# 6. **Water Bodies** – Highly imbalanced binary, needs resampling or rare-event handling.
# 7. **Population Density** – Wide range; log transformation could help reduce skew impact.
# 8. **Day Length** – Fairly uniform; may influence seasonal habitability.
# 9. **Urban / Rural Area** – Binary and imbalanced; check for predictive power.
# 10. **Forested Area** – Rare binary feature; combine or drop if not informative.
# 11. **Crop Area** – Skewed binary; may be more meaningful when grouped with others.
# 12. **Graze Land Area** – Imbalanced; could be merged into a broader land use feature.
# 13. **Habitable** – Binary target with imbalance; modeling should address class imbalance.

# %% [markdown]
# #### 3.8.1. Boxplot for Outlier Detection

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

n_cols = 3 
n_rows = (len(num_cols) + n_cols - 1) // n_cols  

plt.figure(figsize=(n_cols * 5, n_rows * 4))

for i, col in enumerate(num_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Insight :
#
# No outlier as such

# %% [markdown]
# #### 3.8.2. Correlation features with target variable

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

corr_target = numerical_cols.corr()['Habitable'].sort_values(ascending=False)

plt.figure(figsize=(8, 6))
sns.heatmap(corr_target.to_frame(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation of Features with Habitable')
plt.show()

# %% [markdown]
# Insight :
# Water bodies and Natural Resource Score has the highest correlation with the target feature

# %% [markdown]
# #### 3.8.3. Histogram

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
n_cols = 3 
n_rows = (len(num_cols) + n_cols - 1) // n_cols  

plt.figure(figsize=(n_cols * 5, n_rows * 4))

for i, col in enumerate(num_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col], kde=True, color='salmon')
    plt.title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Saving dataset

# %%
df.to_csv('datasets/updated_df.csv', index=False)
